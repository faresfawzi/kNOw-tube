# %%
from quiz.create_quiz import generate_quiz_from_transcript
from transcripts import get_transcript
from dotenv import load_dotenv
from pathlib import Path
import os
from together import Together

# %%
# load_dotenv(Path(__file__).resolve().parent / ".env")
load_dotenv('/Users/faresfawzi/Documents/lauzhack_2025/kNOw-tube/backend/.env')
TOGETHER_API_KEY = os.getenv("TOGETHER_API_KEY")
together_client = Together()

# %%
trans = get_transcript(video_id="VKpaK670U7s")

# %%
generate_quiz_from_transcript(transcript=str(trans), client=together_client, difficulty_level="hard")
# Out:
# Generated Quiz Text: [
#     {
#         "question": "In which year did Apple introduce a product that the speaker claims \"changed the whole computer industry\"?",
#         "options": {
#             "A": "1980",
#             "B": "1984",
#             "C": "1991",
#             "D": "1995"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "The iPhone is described as a combination of three revolutionary products. Which of the following was NOT listed as one of those three components?",
#         "options": {
#             "A": "A widescreen iPod with touch controls",
#             "B": "A revolutionary mobile phone",
#             "C": "A breakthrough internet communications device",
#             "D": "A high‑resolution digital camera"
#         },
#         "correct_answer": "D"
#     },
#     {
#         "question": "When critiquing existing smartphones, the speaker refers to a \"business school 101 graph\" that plots devices on two axes. What are those two axes?",
#         "options": {
#             "A": "Price vs. battery life",
#             "B": "Smartness vs. ease of use",
#             "C": "Size vs. weight",
#             "D": "Speed vs. storage capacity"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "Which of the following smartphones was NOT mentioned by name in the transcript as an example of the current market offerings?",
#         "options": {
#             "A": "Motorola Q",
#             "B": "BlackBerry",
#             "C": "Palm Treo",
#             "D": "Samsung Galaxy S"
#         },
#         "correct_answer": "D"
#     },
#     {
#         "question": "According to the speaker, the core design philosophy behind the iPhone’s user interface is best captured by which of the following statements?",
#         "options": {
#             "A": "Integrate hardware and software for seamless performance",
#             "B": "Prioritize a minimalist aesthetic over functionality",
#             "C": "Replace physical keyboards with a universal touch interface",
#             "D": "Focus on high‑resolution video capabilities"
#         },
#         "correct_answer": "C"
#     }
# ]
# ###################
# [{'question': 'In which year did Apple introduce a product that the speaker claims "changed the whole computer industry"?',
#   'options': {'A': '1980', 'B': '1984', 'C': '1991', 'D': '1995'},
#   'correct_answer': 'B'},
#  {'question': 'The iPhone is described as a combination of three revolutionary products. Which of the following was NOT listed as one of those three components?',
#   'options': {'A': 'A widescreen iPod with touch controls',
#    'B': 'A revolutionary mobile phone',
#    'C': 'A breakthrough internet communications device',
#    'D': 'A high‑resolution digital camera'},
#   'correct_answer': 'D'},
#  {'question': 'When critiquing existing smartphones, the speaker refers to a "business school 101 graph" that plots devices on two axes. What are those two axes?',
#   'options': {'A': 'Price vs. battery life',
#    'B': 'Smartness vs. ease of use',
#    'C': 'Size vs. weight',
#    'D': 'Speed vs. storage capacity'},
#   'correct_answer': 'B'},
#  {'question': 'Which of the following smartphones was NOT mentioned by name in the transcript as an example of the current market offerings?',
#   'options': {'A': 'Motorola Q',
#    'B': 'BlackBerry',
#    'C': 'Palm Treo',
#    'D': 'Samsung Galaxy S'},
#   'correct_answer': 'D'},
#  {'question': 'According to the speaker, the core design philosophy behind the iPhone’s user interface is best captured by which of the following statements?',
#   'options': {'A': 'Integrate hardware and software for seamless performance',
#    'B': 'Prioritize a minimalist aesthetic over functionality',
#    'C': 'Replace physical keyboards with a universal touch interface',
#    'D': 'Focus on high‑resolution video capabilities'},
#   'correct_answer': 'C'}]
