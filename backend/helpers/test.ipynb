# %%
from quiz.create_quiz import generate_quiz_from_transcript
from transcripts import get_transcript
from dotenv import load_dotenv
from pathlib import Path
import os
from together import Together
from flashcards.create_flashcard import generate_multitype_flashcards, generate_qa_flashcards
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from quiz.create_quiz import generate_quiz_from_transcript
#       2 from transcripts import get_transcript
#       3 from dotenv import load_dotenv
#
# File ~/Documents/lauzhack_2025/kNOw-tube/backend/helpers/quiz/create_quiz.py:14
#      11 from together import Together
#      13 from .quiz_prompts import get_prompt_generate_quiz_questions
# ---> 14 from helpers.transcripts import get_transcript
#      16 DEFAULT_MODEL = "openai/gpt-oss-120b"
#      19 def _collapse_transcript_text(
#      20     transcript: Union[str, Mapping[str, str], Sequence[Union[str, Mapping[str, str]]]],
#      21     max_chars: int = 8_000,
#      22 ) -> str:
#
# ModuleNotFoundError: No module named 'helpers.transcripts'; 'helpers' is not a package

# %%
# load_dotenv(Path(__file__).resolve().parent / ".env")
load_dotenv('/Users/faresfawzi/Documents/lauzhack_2025/kNOw-tube/backend/.env')
TOGETHER_API_KEY = os.getenv("TOGETHER_API_KEY")
together_client = Together()

# %%
# trans = get_transcript(video_id="VKpaK670U7s")

# %%
generate_multitype_flashcards(video_id="VKpaK670U7s", time_stamp=2000.0, context_seconds=50, client=together_client)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 generate_multitype_flashcards(video_id="VKpaK670U7s", time_stamp=2000.0, context_seconds=50, client=together_client)
#
# NameError: name 'generate_multitype_flashcards' is not defined
