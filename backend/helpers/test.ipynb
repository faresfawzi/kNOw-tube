# %%
from quiz.create_quiz import generate_quiz_from_transcript
from transcripts import get_transcript
from dotenv import load_dotenv
from pathlib import Path
import os
from together import Together

# %%
# load_dotenv(Path(__file__).resolve().parent / ".env")
load_dotenv('/Users/faresfawzi/Documents/lauzhack_2025/kNOw-tube/backend/.env')
TOGETHER_API_KEY = os.getenv("TOGETHER_API_KEY")
together_client = Together()

# %%
trans = get_transcript(video_id="VKpaK670U7s")

# %%
trans

# %%
generate_quiz_from_transcript(transcript=str(trans), client=together_client, difficulty_level="hard")
# Out:
# Generated Quiz Text: [
#     {
#         "question": "Which product did Apple introduce in 1984?",
#         "options": {
#             "A": "Macintosh",
#             "B": "iPod",
#             "C": "iPhone",
#             "D": "iPad"
#         },
#         "correct_answer": "A"
#     },
#     {
#         "question": "What year did Apple introduce the first iPod?",
#         "options": {
#             "A": "1999",
#             "B": "2001",
#             "C": "2003",
#             "D": "2005"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "According to the speaker, how many devices does the iPhone combine?",
#         "options": {
#             "A": "One",
#             "B": "Two",
#             "C": "Three",
#             "D": "Four"
#         },
#         "correct_answer": "C"
#     },
#     {
#         "question": "What is the name given to the new device Apple is introducing in the video?",
#         "options": {
#             "A": "iPad",
#             "B": "iPhone",
#             "C": "iPod Touch",
#             "D": "MacBook"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "Which of the following is NOT listed as an existing smartphone in the transcript?",
#         "options": {
#             "A": "Motorola Q",
#             "B": "Blackberry",
#             "C": "Palm Treo",
#             "D": "Samsung Galaxy"
#         },
#         "correct_answer": "D"
#     },
#     {
#         "question": "The speaker describes the iPhone as a \"breakthrough internet communications device\". Which three functions does the iPhone combine according to the speaker?",
#         "options": {
#             "A": "Widescreen iPod with touch controls, revolutionary mobile phone, internet communications device",
#             "B": "Desktop computer, music player, camera",
#             "C": "Tablet, smartwatch, e‑reader",
#             "D": "Laptop, phone, GPS"
#         },
#         "correct_answer": "A"
#     },
#     {
#         "question": "What criticism does the speaker give about the user interfaces of existing smartphones?",
#         "options": {
#             "A": "They are too cheap",
#             "B": "They have keyboards that are there whether you need them or not",
#             "C": "They lack color screens",
#             "D": "They are too heavy"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "According to the transcript, what are the two axes used in the \"business school 101 graph\" the speaker mentions?",
#         "options": {
#             "A": "Price vs Performance",
#             "B": "Smart vs Easy‑to‑use",
#             "C": "Size vs Battery",
#             "D": "Speed vs Storage"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "Which term does the speaker use to describe the iPhone's user interface?",
#         "options": {
#             "A": "Revolutionary",
#             "B": "Conventional",
#             "C": "Outdated",
#             "D": "Minimalist"
#         },
#         "correct_answer": "A"
#     },
#     {
#         "question": "The speaker mentions that smartphones combine a phone with what additional capability?",
#         "options": {
#             "A": "Email capability",
#             "B": "GPS navigation",
#             "C": "Video streaming",
#             "D": "Gaming"
#         },
#         "correct_answer": "A"
#     },
#     {
#         "question": "In the speaker's comparison, where do regular cell phones fall on the \"smart vs easy‑to‑use\" graph?",
#         "options": {
#             "A": "High smart, low easy",
#             "B": "Low smart, low easy",
#             "C": "High smart, high easy",
#             "D": "Low smart, high easy"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "Which phrase does the speaker use to describe the iPhone's intended market position relative to previous mobile devices?",
#         "options": {
#             "A": "Incremental upgrade",
#             "B": "Leapfrog product",
#             "C": "Minor tweak",
#             "D": "Sideways move"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "According to the transcript, what is the primary reason the speaker gives for reinventing the phone?",
#         "options": {
#             "A": "To increase profit margins",
#             "B": "To create a product that is smarter and super easy to use",
#             "C": "To reduce manufacturing costs",
#             "D": "To comply with regulations"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "question": "The speaker lists four existing smartphones as \"the usual suspects\". Which of the following is NOT one of those four?",
#         "options": {
#             "A": "Motorola Q",
#             "B": "Blackberry",
#             "C": "Palm Treo",
#             "D": "Apple Newton"
#         },
#         "correct_answer": "D"
#     },
#     {
#         "question": "What does the speaker claim is the result of \"years of research and development\" in the iPhone?",
#         "options": {
#             "A": "A larger battery",
#             "B": "A revolutionary user interface that is an interplay of hardware and software",
#             "C": "A new color scheme",
#             "D": "A lower price point"
#         },
#         "correct_answer": "B"
#     }
# ]
# ###################
# [{'question': 'Which product did Apple introduce in 1984?',
#   'options': {'A': 'Macintosh', 'B': 'iPod', 'C': 'iPhone', 'D': 'iPad'},
#   'correct_answer': 'A'},
#  {'question': 'What year did Apple introduce the first iPod?',
#   'options': {'A': '1999', 'B': '2001', 'C': '2003', 'D': '2005'},
#   'correct_answer': 'B'},
#  {'question': 'According to the speaker, how many devices does the iPhone combine?',
#   'options': {'A': 'One', 'B': 'Two', 'C': 'Three', 'D': 'Four'},
#   'correct_answer': 'C'},
#  {'question': 'What is the name given to the new device Apple is introducing in the video?',
#   'options': {'A': 'iPad', 'B': 'iPhone', 'C': 'iPod Touch', 'D': 'MacBook'},
#   'correct_answer': 'B'},
#  {'question': 'Which of the following is NOT listed as an existing smartphone in the transcript?',
#   'options': {'A': 'Motorola Q',
#    'B': 'Blackberry',
#    'C': 'Palm Treo',
#    'D': 'Samsung Galaxy'},
#   'correct_answer': 'D'},
#  {'question': 'The speaker describes the iPhone as a "breakthrough internet communications device". Which three functions does the iPhone combine according to the speaker?',
#   'options': {'A': 'Widescreen iPod with touch controls, revolutionary mobile phone, internet communications device',
#    'B': 'Desktop computer, music player, camera',
#    'C': 'Tablet, smartwatch, e‑reader',
#    'D': 'Laptop, phone, GPS'},
#   'correct_answer': 'A'},
#  {'question': 'What criticism does the speaker give about the user interfaces of existing smartphones?',
#   'options': {'A': 'They are too cheap',
#    'B': 'They have keyboards that are there whether you need them or not',
#    'C': 'They lack color screens',
#    'D': 'They are too heavy'},
#   'correct_answer': 'B'},
#  {'question': 'According to the transcript, what are the two axes used in the "business school 101 graph" the speaker mentions?',
#   'options': {'A': 'Price vs Performance',
#    'B': 'Smart vs Easy‑to‑use',
#    'C': 'Size vs Battery',
#    'D': 'Speed vs Storage'},
#   'correct_answer': 'B'},
#  {'question': "Which term does the speaker use to describe the iPhone's user interface?",
#   'options': {'A': 'Revolutionary',
#    'B': 'Conventional',
#    'C': 'Outdated',
#    'D': 'Minimalist'},
#   'correct_answer': 'A'},
#  {'question': 'The speaker mentions that smartphones combine a phone with what additional capability?',
#   'options': {'A': 'Email capability',
#    'B': 'GPS navigation',
#    'C': 'Video streaming',
#    'D': 'Gaming'},
#   'correct_answer': 'A'},
#  {'question': 'In the speaker\'s comparison, where do regular cell phones fall on the "smart vs easy‑to‑use" graph?',
#   'options': {'A': 'High smart, low easy',
#    'B': 'Low smart, low easy',
#    'C': 'High smart, high easy',
#    'D': 'Low smart, high easy'},
#   'correct_answer': 'B'},
#  {'question': "Which phrase does the speaker use to describe the iPhone's intended market position relative to previous mobile devices?",
#   'options': {'A': 'Incremental upgrade',
#    'B': 'Leapfrog product',
#    'C': 'Minor tweak',
#    'D': 'Sideways move'},
#   'correct_answer': 'B'},
#  {'question': 'According to the transcript, what is the primary reason the speaker gives for reinventing the phone?',
#   'options': {'A': 'To increase profit margins',
#    'B': 'To create a product that is smarter and super easy to use',
#    'C': 'To reduce manufacturing costs',
#    'D': 'To comply with regulations'},
#   'correct_answer': 'B'},
#  {'question': 'The speaker lists four existing smartphones as "the usual suspects". Which of the following is NOT one of those four?',
#   'options': {'A': 'Motorola Q',
#    'B': 'Blackberry',
#    'C': 'Palm Treo',
#    'D': 'Apple Newton'},
#   'correct_answer': 'D'},
#  {'question': 'What does the speaker claim is the result of "years of research and development" in the iPhone?',
#   'options': {'A': 'A larger battery',
#    'B': 'A revolutionary user interface that is an interplay of hardware and software',
#    'C': 'A new color scheme',
#    'D': 'A lower price point'},
#   'correct_answer': 'B'}]
